# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('train_cars.csv')
test=pd.read_csv('test_cars.csv')

# %%
train.sort_values(["Name","Price"]).head(40)
# Out:
#                             Name    Location  Year  Kilometers_Driven  \
# 9517   Audi A3 35 TDI Attraction     Kolkata  2007              62934
# 3090   Audi A3 35 TDI Attraction      Mumbai  2011              71228
# 16436  Audi A3 35 TDI Attraction      Mumbai  2012              22106
# 19745  Audi A3 35 TDI Attraction      Mumbai  2009              43547
# 16394  Audi A3 35 TDI Attraction      Mumbai  2012              49301
# 8307   Audi A3 35 TDI Attraction      Mumbai  2017              54679
# 7626   Audi A3 35 TDI Attraction      Mumbai  2009              49876
# 8928   Audi A3 35 TDI Attraction      Jaipur  2015              55227
# 18145  Audi A3 35 TDI Attraction   Hyderabad  2015              42344
# 2352   Audi A3 35 TDI Attraction      Mumbai  2012              44666
# 17124  Audi A3 35 TDI Attraction      Jaipur  2009              34431
# 21051  Audi A3 35 TDI Attraction   Hyderabad  2014              54518
# 10801  Audi A3 35 TDI Attraction     Kolkata  2015              34417
# 20384  Audi A3 35 TDI Attraction     Kolkata  2009              70200
# 3493   Audi A3 35 TDI Attraction   Ahmedabad  2016              24758
# 19477  Audi A3 35 TDI Attraction     Kolkata  2016               8734
# 8380   Audi A3 35 TDI Attraction        Pune  2009              51614
# 4331   Audi A3 35 TDI Attraction      Jaipur  2011              49851
# 2751      Audi A3 35 TDI Premium   Ahmedabad  2016              39500
# 15849     Audi A3 35 TDI Premium  Coimbatore  2018               8316
# 3800      Audi A3 35 TDI Premium      Mumbai  2017              43835
# 4425            Audi A4 1.8 TFSI   Hyderabad  2010              33893
# 14128           Audi A4 1.8 TFSI     Kolkata  2009              38559
# 12537           Audi A4 1.8 TFSI      Mumbai  2007              57033
# 13657           Audi A4 1.8 TFSI   Hyderabad  2014              63045
# 13063           Audi A4 1.8 TFSI       Kochi  2012              51274
# 7590            Audi A4 1.8 TFSI      Mumbai  2004              61948
# 21293           Audi A4 1.8 TFSI      Mumbai  2010              90339
# 10817           Audi A4 1.8 TFSI     Chennai  2010              71585
# 1811            Audi A4 1.8 TFSI   Hyderabad  2015              51782
# 10632           Audi A4 1.8 TFSI   Hyderabad  2011              50736
# 20752           Audi A4 1.8 TFSI       Delhi  2013              69670
# 706             Audi A4 1.8 TFSI       Kochi  2016              46623
# 8612            Audi A4 1.8 TFSI     Kolkata  2010               7322
# 1155            Audi A4 1.8 TFSI     Chennai  2013              51508
# 8969            Audi A4 1.8 TFSI   Hyderabad  2013              63387
# 20413           Audi A4 1.8 TFSI      Mumbai  2013              46376
# 2943            Audi A4 1.8 TFSI  Coimbatore  2015              30858
# 2454            Audi A4 1.8 TFSI     Chennai  2013              35178
# 17934           Audi A4 1.8 TFSI   Hyderabad  2015              57590
#
#       Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  \
# 9517        CNG       Manual      Third  19.87 kmpl  1388 CC  108.45 bhp
# 3090     Diesel       Manual      First  17.19 kmpl   998 CC    73.9 bhp
# 16436    Petrol       Manual      First   17.0 kmpl   796 CC    67.1 bhp
# 19745    Petrol       Manual      First  12.99 kmpl  1086 CC    53.3 bhp
# 16394    Petrol       Manual      First   17.8 kmpl  2143 CC    67.1 bhp
# 8307     Petrol       Manual      First  20.36 kmpl  1197 CC    83.1 bhp
# 7626     Petrol       Manual      First  20.37 kmpl  1794 CC      74 bhp
# 8928     Petrol       Manual      First   12.4 kmpl  1198 CC    79.4 bhp
# 18145    Diesel       Manual      First  19.69 kmpl  2477 CC   58.16 bhp
# 2352     Petrol       Manual      First   22.0 kmpl   998 CC      74 bhp
# 17124       CNG       Manual      First  19.81 kmpl  2112 CC    88.2 bhp
# 21051    Diesel       Manual      First  20.77 kmpl  1582 CC    74.9 bhp
# 10801    Petrol       Manual      First   12.4 kmpl  2494 CC   73.75 bhp
# 20384    Petrol       Manual      First   18.7 kmpl  1197 CC      82 bhp
# 3493     Petrol       Manual      First  18.59 kmpl  2494 CC    null bhp
# 19477    Petrol       Manual      First   13.7 kmpl  1794 CC     306 bhp
# 8380     Diesel    Automatic      First   12.8 kmpl  1991 CC     171 bhp
# 4331     Diesel    Automatic      First   12.8 kmpl  1461 CC    88.5 bhp
# 2751     Diesel    Automatic      First   8.77 kmpl  1599 CC     395 bhp
# 15849    Petrol    Automatic      First  18.44 kmpl  1468 CC   71.01 bhp
# 3800     Petrol       Manual      First  12.81 kmpl  1978 CC  281.61 bhp
# 4425     Petrol    Automatic      First  26.6 km/kg  2987 CC   68.05 bhp
# 14128    Petrol       Manual      First  25.17 kmpl  1364 CC     118 bhp
# 12537    Petrol       Manual      First   18.9 kmpl  1197 CC    null bhp
# 13657    Petrol       Manual      First   17.0 kmpl   998 CC   126.2 bhp
# 13063    Diesel       Manual      First   18.0 kmpl  1198 CC   67.04 bhp
# 7590     Petrol       Manual      First   12.8 kmpl  1186 CC     136 bhp
# 21293    Petrol       Manual     Second   24.0 kmpl  1197 CC     204 bhp
# 10817    Diesel       Manual      First   15.0 kmpl   998 CC    null bhp
# 1811     Petrol       Manual      First  25.44 kmpl   998 CC   68.05 bhp
# 10632    Petrol       Manual      First   16.8 kmpl   998 CC   335.2 bhp
# 20752    Diesel       Manual      First   11.0 kmpl   998 CC  108.45 bhp
# 706      Petrol       Manual      First  18.06 kmpl  1798 CC      70 bhp
# 8612     Petrol       Manual      First  11.33 kmpl  1399 CC   198.5 bhp
# 1155     Diesel       Manual      First  15.63 kmpl  2993 CC     140 bhp
# 8969     Diesel       Manual      First   28.4 kmpl   998 CC      84 bhp
# 20413    Diesel       Manual      First  17.05 kmpl  3198 CC  126.32 bhp
# 2943     Petrol    Automatic      First   16.9 kmpl  1591 CC      47 bhp
# 2454     Petrol       Manual      First   23.0 kmpl  1999 CC   335.3 bhp
# 17934    Diesel    Automatic      First   22.7 kmpl  2148 CC   58.16 bhp
#
#        Seats   New_Price  Price
# 9517     5.0         NaN   2.01
# 3090     5.0         NaN   2.16
# 16436    5.0         NaN   2.17
# 19745    5.0         NaN   2.17
# 16394    5.0         NaN   2.38
# 8307     5.0         NaN   2.72
# 7626     5.0         NaN   3.30
# 8928     5.0         NaN   3.56
# 18145    5.0         NaN   3.57
# 2352     5.0         NaN   3.64
# 17124    5.0         NaN   3.68
# 21051    5.0   8.44 Lakh   4.17
# 10801    5.0         NaN   4.96
# 20384    5.0         NaN   5.38
# 3493     8.0   8.61 Lakh   6.21
# 19477    5.0         NaN  11.44
# 8380     5.0         NaN  13.91
# 4331     7.0         NaN  21.54
# 2751     5.0  15.68 Lakh   3.67
# 15849    5.0  35.29 Lakh   5.69
# 3800     5.0     1.28 Cr  22.00
# 4425     5.0         NaN   1.64
# 14128    5.0         NaN   1.84
# 12537    5.0         NaN   1.90
# 13657    5.0         NaN   2.02
# 13063    5.0         NaN   2.04
# 7590     5.0         NaN   2.08
# 21293    5.0  15.68 Lakh   2.35
# 10817    5.0         NaN   2.47
# 1811     5.0         NaN   2.64
# 10632    5.0         NaN   2.78
# 20752    5.0         NaN   3.29
# 706      5.0         NaN   3.69
# 8612     5.0         NaN   4.14
# 1155     5.0         NaN   4.51
# 8969     5.0         NaN   5.78
# 20413    5.0         NaN   6.16
# 2943     5.0  11.02 Lakh   7.77
# 2454     4.0         NaN  11.52
# 17934    7.0         NaN  15.91

# %%
comb=pd.concat([train,test],axis=0)
comb.isnull().sum()
# Out:
# Name                     0
# Location                 0
# Year                     0
# Kilometers_Driven        0
# Fuel_Type                0
# Transmission             0
# Owner_Type               0
# Mileage                341
# Engine                 106
# Power                  317
# Seats                  338
# New_Price            61934
# Price                52500
# dtype: int64

# %%
comb.head()
    
comb["Brand"]=[i[0] for i in comb["Name"].str.split()]

# %%
comb["M1"]=[i[1] for i in comb["Name"].str.split()]
comb["M2"]=[i[2] for i in comb["Name"].str.split()]
comb["M3"]=[i[-1] for i in comb["Name"].str.split()]

# %%
comb.drop("Name",axis=1,inplace=True)

# %%
comb.head()
# Out:
#      Location  Year  Kilometers_Driven Fuel_Type Transmission Owner_Type  \
# 0   Bangalore  2012              33715    Diesel       Manual      First
# 1       Delhi  2013              73977    Diesel       Manual      First
# 2       Delhi  2007              16460       CNG       Manual      Third
# 3     Kolkata  2009              35048    Petrol       Manual      First
# 4  Coimbatore  2013              41656    Petrol    Automatic      First
#
#       Mileage   Engine     Power  Seats   New_Price  Price    Brand    M1  \
# 0  16.46 kmpl  1248 CC   100 bhp    5.0  43.65 Lakh  25.53   Maruti   800
# 1   18.6 kmpl  2993 CC    61 bhp    4.0         NaN   4.58    Honda  City
# 2   15.3 kmpl  1599 CC   140 bhp    5.0         NaN   2.37    Honda  CR-V
# 3  25.47 kmpl  1196 CC  86.8 bhp    5.0         NaN   1.20    Skoda  Yeti
# 4  19.12 kmpl  1999 CC   115 bhp    7.0  13.26 Lakh  33.04  Hyundai   i10
#
#          M2     M3
# 0       Std  BSIII
# 1       1.5     AT
# 2       RVi     MT
# 3  Ambition    4X2
# 4     Magna    LPG

# %%
comb["Location"].value_counts()
def loc(i):
    if i in ["Delhi", "Mumbai", "Bangalore", "Chennai", "Hyderabad", "Kolkata", "Ahmedabad","Pune"]:
        return 1
    else:
        return 0
    
comb["Location"]=comb["Location"].apply(loc)

# %%
comb["old"]=2022-comb.Year

# %%
comb.drop("Year",axis=1,inplace=True)

# %%
comb=pd.concat([comb,pd.get_dummies(comb.Fuel_Type,drop_first=True)],axis=1)

# %%
comb.drop("Fuel_Type",axis=1,inplace=True)

# %%
comb.Transmission.value_counts()
def trans(i):
    if i=="Manual":
        return 0
    else:
        return 1
    
comb["Transmission"]=comb.Transmission.apply(trans)

# %%
comb.head()
comb.Owner_Type.value_counts()
def own(i):
    if i=="Fourth & Above":
        return 0
    elif i=="Third":
        return 1
    elif i=="Second":
        return 2
    else:
        return 3
    
comb.Owner_Type=comb.Owner_Type.apply(own)

# %%
comb.Mileage=pd.to_numeric(comb.Mileage.replace(regex=["kmpl","km/kg"],value=""))

# %%
comb.head()
comb.Engine=pd.to_numeric(comb.Engine.replace(regex=["CC"],value=""))

# %%
comb.head()
comb.Power=pd.to_numeric(comb.Power.replace(regex=["bhp","null"],value=["",np.NaN]))

# %%
comb.head()
#comb.New_Price=
comb.New_Price=pd.to_numeric(comb.New_Price.replace(regex=["Lakh","Cr"],value=""))

# %%
pd.get_dummies(comb.Brand,drop_first=True)
from sklearn.decomposition import PCA
pca=PCA(n_components=15)
brand_pca=pd.DataFrame(pca.fit_transform(pd.get_dummies(comb["Brand"],drop_first=True)))
sum(pca.explained_variance_ratio_)
# Out:
# 0.951415147626782

# %%
comb.M3.value_counts()
pca=PCA(n_components=5)
model_pca=pd.DataFrame(pca.fit_transform(pd.get_dummies(comb[["M1","M2","M3"]],drop_first=True)),columns=["MP1","MP2","MP3","MP4","MP5"])
sum(pca.explained_variance_ratio_)
# Out:
# 0.11564200821370829

# %%
#pd.concat([comb,brand_pca.reset_index()],axis=1)
df=pd.concat([pd.concat([comb.reset_index(),brand_pca.reset_index()],axis=1),model_pca],axis=1).drop(["Brand","M1","M2","M3"],axis=1)

# %%
df=df.drop("index",axis=1)

# %%
df.iloc[:,:10].corr()
df=df.sort_values(["Transmission","Seats","Engine"]).drop("New_Price",axis=1)

# %%
# Out:
# array([[ 0.00000000e+00,  3.23420000e+04,  0.00000000e+00, ...,
#         -2.47419767e-01,  7.24814940e-01,  1.78650514e-01],
#        [ 1.00000000e+00,  1.00509000e+05,  0.00000000e+00, ...,
#         -7.28850643e-02, -3.93872137e-02, -2.29039730e-02],
#        [ 1.00000000e+00,  3.96550000e+04,  0.00000000e+00, ...,
#         -2.51750931e-01,  7.38945153e-01,  1.82268717e-01],
#        ...,
#        [ 1.00000000e+00,  6.53720000e+04,  1.00000000e+00, ...,
#         -2.63472962e-01,  7.48467717e-01,  1.74010066e-01],
#        [ 1.00000000e+00,  7.31560000e+04,  1.00000000e+00, ...,
#         -2.63472962e-01,  7.48467717e-01,  1.74010066e-01],
#        [ 1.00000000e+00,  4.75590000e+04,  1.00000000e+00, ...,
#         -2.10444981e-01, -6.17563643e-01,  8.23993946e-01]])

# %%
#df=df.ffill().bfill().reset_index().drop("index",axis=1)
from sklearn.impute import KNNImputer
knn=KNNImputer(n_neighbors=5)
df=knn.fit_transform(df)
# Out:
# /Users/iamyk/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# /Users/iamyk/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(

# %%
#from sklearn.preprocessing import StandardScaler
#scaler=StandardScaler()
#scaled=pd.DataFrame(scaler.fit_transform(df[["Kilometers_Driven","Mileage","Engine","Power"]]),columns=["Kilometers_Driven_sc","Mileage_sc","Engine_sc","Power_sc"])

# %%
#df1=pd.concat([df,scaled],axis=1).drop(["Kilometers_Driven","Mileage","Engine","Power"],axis=1)

# %%
train.shape
df_train=df.iloc[:22500,:]
df_test=df.iloc[22500:,:]
xtrain=df_train.drop("Price",axis=1)
ytrain=df_train["Price"]
xtest=df_test.drop("Price",axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_p/58kk_nm95gqc3fv9fyyzh_480000gn/T/ipykernel_12579/1753417745.py in <module>
#       1 train.shape
# ----> 2 df_train=df.iloc[:22500,:]
#       3 df_test=df.iloc[22500:,:]
#       4 xtrain=df_train.drop("Price",axis=1)
#       5 ytrain=df_train["Price"]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'iloc'

# %%
from sklearn.metrics import mean_squared_error

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x1,x2,y1,y2=train_test_split(xtrain,ytrain,test_size=0.25)
lin=LinearRegression()
model=lin.fit(x1,y1)
ypred=model.predict(x2)
mean_squared_error(y2,ypred)

# %%
lin=LinearRegression()
from lightgbm import LGBMRegressor
lgb=LGBMRegressor()
model=lgb.fit(xtrain,ytrain)
preds=model.predict(xtest)
preds

# %%
sub=pd.DataFrame({"Name":test.Name,"Price":preds})
sub.to_csv("c2.csv",index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.rcParams['figure.figsize']=[13,9]
sns.heatmap(comb.corr(),annot=True)
# Out:
# <AxesSubplot:>
